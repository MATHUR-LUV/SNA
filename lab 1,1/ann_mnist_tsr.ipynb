# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load MNIST
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize & flatten
x_train = x_train.reshape(-1, 28*28) / 255.0
x_test  = x_test.reshape(-1, 28*28) / 255.0

# ANN model
model = models.Sequential([
    layers.Dense(256, activation='relu', input_shape=(784,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.1)

# Evaluate
model.evaluate(x_test, y_test)
# Out:
# 2026-01-30 11:40:45.898019: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 11:40:45.950073: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 11:40:45.950884: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-30 11:40:46.795830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Epoch 1/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.2864 - accuracy: 0.9188 - val_loss: 0.1152 - val_accuracy: 0.9660
# Epoch 2/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1080 - accuracy: 0.9678 - val_loss: 0.0864 - val_accuracy: 0.9752
# Epoch 3/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0683 - accuracy: 0.9792 - val_loss: 0.0816 - val_accuracy: 0.9767
# Epoch 4/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0502 - accuracy: 0.9847 - val_loss: 0.0848 - val_accuracy: 0.9770
# Epoch 5/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.0726 - val_accuracy: 0.9795
# Epoch 6/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0274 - accuracy: 0.9912 - val_loss: 0.0721 - val_accuracy: 0.9803
# Epoch 7/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0214 - accuracy: 0.9934 - val_loss: 0.0811 - val_accuracy: 0.9797
# Epoch 8/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 0.0781 - val_accuracy: 0.9798
# Epoch 9/10
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 0.0873 - val_accuracy: 0.9788
# Epoch 10/10
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0829 - val_accuracy: 0.9790
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0817 - accuracy: 0.9777
# [0.08172181993722916, 0.9776999950408936]
