# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load CIFAR-10
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize & flatten
x_train = x_train.reshape(-1, 32*32*3) / 255.0
x_test  = x_test.reshape(-1, 32*32*3) / 255.0

# ANN model
model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
model.fit(x_train, y_train, epochs=20, batch_size=128, validation_split=0.1)

# Evaluate
model.evaluate(x_test, y_test)
# Out:
# 2026-01-30 11:42:16.339652: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 11:42:16.381458: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 11:42:16.382338: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-30 11:42:17.158595: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 21s 0us/step
# Epoch 1/20
# 2026-01-30 11:42:43.523643: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 552960000 exceeds 10% of free system memory.
# 352/352 [==============================] - 9s 23ms/step - loss: 1.9031 - accuracy: 0.3118 - val_loss: 1.7887 - val_accuracy: 0.3588
# Epoch 2/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.7023 - accuracy: 0.3879 - val_loss: 1.6877 - val_accuracy: 0.4038
# Epoch 3/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.6069 - accuracy: 0.4250 - val_loss: 1.6277 - val_accuracy: 0.4178
# Epoch 4/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.5451 - accuracy: 0.4481 - val_loss: 1.6089 - val_accuracy: 0.4226
# Epoch 5/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.5026 - accuracy: 0.4632 - val_loss: 1.5433 - val_accuracy: 0.4502
# Epoch 6/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.4698 - accuracy: 0.4751 - val_loss: 1.4879 - val_accuracy: 0.4736
# Epoch 7/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.4416 - accuracy: 0.4867 - val_loss: 1.5104 - val_accuracy: 0.4660
# Epoch 8/20
# 352/352 [==============================] - 8s 21ms/step - loss: 1.4042 - accuracy: 0.4990 - val_loss: 1.4836 - val_accuracy: 0.4716
# Epoch 9/20
# 352/352 [==============================] - 7s 21ms/step - loss: 1.3808 - accuracy: 0.5048 - val_loss: 1.4683 - val_accuracy: 0.4746
# Epoch 10/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.3666 - accuracy: 0.5124 - val_loss: 1.4720 - val_accuracy: 0.4824
# Epoch 11/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.3234 - accuracy: 0.5280 - val_loss: 1.4714 - val_accuracy: 0.4704
# Epoch 12/20
# 352/352 [==============================] - 8s 24ms/step - loss: 1.3114 - accuracy: 0.5334 - val_loss: 1.4270 - val_accuracy: 0.4922
# Epoch 13/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.2935 - accuracy: 0.5376 - val_loss: 1.4121 - val_accuracy: 0.5032
# Epoch 14/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.2687 - accuracy: 0.5477 - val_loss: 1.4272 - val_accuracy: 0.4872
# Epoch 15/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.2433 - accuracy: 0.5558 - val_loss: 1.4096 - val_accuracy: 0.4966
# Epoch 16/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.2194 - accuracy: 0.5637 - val_loss: 1.3973 - val_accuracy: 0.5116
# Epoch 17/20
# 352/352 [==============================] - 8s 23ms/step - loss: 1.1978 - accuracy: 0.5711 - val_loss: 1.4025 - val_accuracy: 0.5124
# Epoch 18/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.1740 - accuracy: 0.5821 - val_loss: 1.3828 - val_accuracy: 0.5130
# Epoch 19/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.1517 - accuracy: 0.5895 - val_loss: 1.4125 - val_accuracy: 0.4972
# Epoch 20/20
# 352/352 [==============================] - 8s 22ms/step - loss: 1.1309 - accuracy: 0.5942 - val_loss: 1.3832 - val_accuracy: 0.5224
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3966 - accuracy: 0.5153
# [1.3965615034103394, 0.5152999758720398]
