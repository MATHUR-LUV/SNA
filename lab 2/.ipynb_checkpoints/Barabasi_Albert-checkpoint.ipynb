# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

n = 5000
m = 4

print("n =", n)
print("m =", m)
print("--------------------------------------------------")

G = nx.barabasi_albert_graph(n, m)

degrees = [deg for node, deg in G.degree()]

degree_count = Counter(degrees)
deg, count = zip(*sorted(degree_count.items()))

mean_degree = np.mean(degrees)
var_degree = np.var(degrees)

clustering = nx.average_clustering(G)

print("Mean degree:", mean_degree)
print("Variance of degree:", var_degree)
print("Clustering coefficient:", clustering)

plt.figure()
plt.scatter(deg, count)
plt.xlabel("Degree (k)")
plt.ylabel("Number of Nodes")
plt.title("BA Degree Distribution (Linear Scale)")
plt.show()

plt.figure()
plt.scatter(deg, count)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Degree (k) [log]")
plt.ylabel("Number of Nodes [log]")
plt.title("BA Degree Distribution (Log-Log Scale)")
plt.show()
# Out:
# n = 5000
# m = 4
# --------------------------------------------------
# Mean degree: 7.9936
# Variance of degree: 105.15235904000001
# Clustering coefficient: 0.01041157039290754
